# %% [markdown]
# ## Máster en Big Data y Data Science
#
# ### Metodologías de gestión y diseño de proyectos de big data
#
# #### Sesión Práctica 01 - Introducción
#
# ---
#
# En esta libreta se realiza la importación de las librerías a utilizar durante la ejecución de la práctica de la asignatura. El objetivo es verificar que el entorno especificado haya podido ser replicado en el equipo de cada estudiante.

# %%
import matplotlib.pyplot as plt
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
print(sys.executable)
# Out:
# c:\Users\Maria Lasso\AppData\Local\Programs\Python\Python311\python.exe

# %%
! "C:\Users\Maria Lasso\AppData\Local\Programs\Python\Python311\python.exe" -m pip install \
numpy matplotlib mlflow scikit-learn ydata-profiling streamlit fastapi pytest pandera great-expectations
# Out:
# ...
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import mlflow
import sklearn
import ydata_profiling as ydp
import streamlit as st
import fastapi as fa
import pytest as pt
import pandera as pa
import great_expectations as gx

print("Pandas version: ", pd.__version__)
print("Numpy version: ", np.__version__)
print("Matplotlib version: ", plt.__version__)
print("MLFlow version: ", mlflow.__version__)
print("Sklearn version: ", sklearn.__version__)
print("YData Profiling version: ", ydp.__version__)
print("Streamlit version: ", st.__version__)
print("FastAPI version: ", fa.__version__)
print("PyTest version: ", pt.__version__)
print("Pandera version: ", pa.__version__)
print("Great Expectations version: ", gx.__version__)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[28], line 6
#       4 import mlflow
#       5 import sklearn
# ----> 6 import ydata_profiling as ydp
#       7 import streamlit as st
#       8 import fastapi as fa
#
# File c:\Users\Maria Lasso\AppData\Local\Programs\Python\Python311\Lib\site-packages\ydata_profiling\__init__.py:24
#      22 spec_numba = importlib.util.find_spec("numba")
#      23 if spec_numba is not None:
# ---> 24     from numba.core.errors import NumbaDeprecationWarning  # isort:skip # noqa
#      26     warnings.simplefilter("ignore", category=NumbaDeprecationWarning)
#      28 __all__ = [
#      29     "pandas_decorator",
#      30     "ProfileReport",
#      31     "__version__",
#      32     "compare",
#      33 ]
#
# File c:\Users\Maria Lasso\AppData\Local\Programs\Python\Python311\Lib\site-packages\numba\__init__.py:59
# ...
